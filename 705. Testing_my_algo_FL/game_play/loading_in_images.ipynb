# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-48f101843100> in <module>
# ----> 1 np.linspace(0,0,1)
#
# NameError: name 'np' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
np.linspace(0,0,1)
# Out:
# array([0.])

# %%
road_tile_file = "/Users/jacoblourie/Desktop/road_tile.jpg"
road_tile = np.array((Image.open(road_tile_file)).resize((24,24), resample=Image.BILINEAR))[:,:,:3]

car_on_road_tile_file = "/Users/jacoblourie/Desktop/car_on_road_tile.png"
car_on_road_tile = np.array((Image.open(car_on_road_tile_file)).resize((24,24), resample=Image.NEAREST))[:,:,:3]

tree_file = "/Users/jacoblourie/Desktop/tree_file.png"
tree_tile = np.array((Image.open(tree_file)).resize((24,24), resample=Image.NEAREST))[:,:,:3]

car_hit_tree_file = "/Users/jacoblourie/Desktop/car_hit_tree.png"
car_hit_tree_tile = np.array((Image.open(car_hit_tree_file)).resize((24,24), resample=Image.NEAREST))[:,:,:3]

swamp_file = "/Users/jacoblourie/Desktop/swamp_file.png"
swamp_tile = np.array((Image.open(swamp_file)).resize((24,24), resample=Image.NEAREST))[:,:,:3]

car_on_swamp_file = "/Users/jacoblourie/Desktop/car_on_swamp.png"
car_on_swamp_tile = np.array((Image.open(car_on_swamp_file)).resize((24,24), resample=Image.NEAREST))[:,:,:3]

finish_line_file = "/Users/jacoblourie/Desktop/finish_line.png"
finish_line_tile = np.array((Image.open(finish_line_file)).resize((24,24), resample=Image.NEAREST))[:,:,:3]

car_on_finish_line_file = "/Users/jacoblourie/Desktop/car_on_finish_line.png"
car_on_finish_line_tile = np.array((Image.open(car_on_finish_line_file)).resize((24,24), resample=Image.NEAREST))[:,:,:3]

# %%
plt.imshow(car_on_road_tile); plt.show()
plt.imshow(tree_tile); plt.show()
plt.imshow(car_hit_tree_tile); plt.show()
plt.imshow(swamp_tile); plt.show()
plt.imshow(car_on_swamp_tile); plt.show()
plt.imshow(finish_line_tile); plt.show()
plt.imshow(car_on_finish_line_tile); plt.show()

# %%
# Out:
# (48, 48, 3)

# %%
car_turn_left_on_road = np.array(car_on_road_im.rotate(45).resize((24,24), resample=Image.NEAREST))
